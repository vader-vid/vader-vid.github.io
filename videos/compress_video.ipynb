# %%
# import
from transformers import AutoProcessor, AutoModel
from PIL import Image
import torch
import numpy as np
import torchvision
# Out:
# /home/zheyangq/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
import subprocess
import os

def compress_video(input_file, output_file, crf=28):
    """
    Compress a video file using H.265 codec (HEVC).

    Args:
    - input_file (str): Path to the input video file.
    - output_file (str): Path to save the compressed video file.
    - crf (int): Constant Rate Factor for quality control (0-51, where lower is better quality).
    """
    # command = [
    #     'ffmpeg',
    #     '-i', input_file,
    #     '-c:v', 'libx265',
    #     '-crf', str(crf),
    #     '-preset', 'medium',  # other options: ultrafast, superfast, veryfast, faster, fast, slow, slower, veryslow
    #     output_file
    # ]
    command = [
        'ffmpeg',
        '-i', input_file,
        '-c:v', 'libx265',
        '-crf', str(crf),
        '-preset', 'medium',
        '-tag:v', 'hvc1',  # Ensure compatibility with Safari
        '-c:a', 'aac',  # Use AAC audio codec for compatibility
        output_file
    ]

    subprocess.run(command, check=True)

folder = 'row7'

# loop through all the video files in the folder
for file in os.listdir(folder):
    if file.endswith('.mp4'):
        input_file = os.path.join(folder, file)
        output_file = os.path.join(folder, 'compressed_' + file)
        compress_video(input_file, output_file, crf=18)

# output_file = 'output.mp4'
# compress_video(input_file, output_file, crf=18)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/0_0_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 2852 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 2849 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_0_0_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.0 Lsize=     320kB time=00:00:02.10 bitrate=1246.4kbits/s speed=4.85x
# video:316kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 1.090624%
# x265 [info]: frame I:      1, Avg QP:16.01  kb/s: 2359.28
# x265 [info]: frame P:      5, Avg QP:16.55  kb/s: 1728.06
# x265 [info]: frame B:     18, Avg QP:20.50  kb/s: 827.01
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.41s (58.05 fps), 1078.57 kb/s, Avg QP:19.49
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/0_2_0001.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 2454 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 2450 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_0_2_0001.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.0 Lsize=     247kB time=00:00:02.10 bitrate= 964.1kbits/s speed=5.33x
# video:244kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 1.414558%
# x265 [info]: frame I:      1, Avg QP:14.15  kb/s: 2712.24
# x265 [info]: frame P:      5, Avg QP:15.64  kb/s: 1573.47
# x265 [info]: frame B:     18, Avg QP:20.60  kb/s: 520.92
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.38s (63.48 fps), 831.51 kb/s, Avg QP:19.30
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/0_2_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 3421 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 3418 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_0_2_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=20.6 Lsize=     381kB time=00:00:02.10 bitrate=1484.4kbits/s speed=4.29x
# video:377kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.914162%
# x265 [info]: frame I:      1, Avg QP:15.00  kb/s: 2818.24
# x265 [info]: frame P:      5, Avg QP:16.00  kb/s: 2091.36
# x265 [info]: frame B:     18, Avg QP:20.21  kb/s: 978.28
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.47s (50.89 fps), 1286.83 kb/s, Avg QP:19.12
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/0_2_0004.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 4765 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 4762 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_0_2_0004.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.2 Lsize=     513kB time=00:00:02.10 bitrate=2002.0kbits/s speed=3.67x
# video:510kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0
B audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.703956%
# x265 [info]: frame I:      1, Avg QP:15.81  kb/s: 3449.44
# x265 [info]: frame P:      5, Avg QP:16.51  kb/s: 2692.34
# x265 [info]: frame B:     18, Avg QP:20.77  kb/s: 1288.74
# x265 [info]: Weighted P-Frames: Y:20.0% UV:20.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.56s (43.13 fps), 1671.19 kb/s, Avg QP:19.68
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/3_0_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
# ...
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_6_2_0001.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.6 Lsize=     398kB time=00:00:02.10 bitrate=1553.7kbits/s speed=3.15x
# video:395kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.873010%
# x265 [info]: frame I:      1, Avg QP:15.07  kb/s: 3875.36
# x265 [info]: frame P:      5, Avg QP:16.16  kb/s: 2434.67
# x265 [info]: frame B:     18, Avg QP:21.05  kb/s: 905.08
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.66s (36.61 fps), 1347.51 kb/s, Avg QP:19.78
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/7_0_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 3988 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 3984 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_7_0_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps= 22 q=21.4 Lsize=     482kB time=00:00:02.10 bitrate=1879.4kbits/s speed=1.95x
# video:478kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.720667%
# x265 [info]: frame I:      1, Avg QP:15.45  kb/s: 3758.72
# x265 [info]: frame P:      5, Avg QP:16.45  kb/s: 2633.15
# x265 [info]: frame B:     18, Avg QP:20.94  kb/s: 1236.32
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 1.02s (23.56 fps), 1632.43 kb/s, Avg QP:19.77
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/7_1_0001.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 3097 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 3094 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_7_1_0001.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.7 Lsize=     366kB time=00:00:02.10 bitrate=1425.8kbits/s speed=2.26x
# video:362kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.952104%
# x265 [info]: frame I:      1, Avg QP:14.87  kb/s: 3613.44
# x265 [info]: frame P:      5, Avg QP:16.27  kb/s: 2037.66
# x265 [info]: frame B:     18, Avg QP:21.15  kb/s: 880.62
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.92s (25.96 fps), 1235.54 kb/s, Avg QP:19.87
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'row7/9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 3963 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x384, 3959 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'row7/compressed_9.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x384, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=20.9 Lsize=     552kB time=00:00:02.10 bitrate=2154.4kbits/s speed=3.39x
# video:549kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.628094%
# x265 [info]: frame I:      1, Avg QP:16.42  kb/s: 3162.48
# x265 [info]: frame P:      5, Avg QP:16.98  kb/s: 2667.44
# x265 [info]: frame B:     18, Avg QP:20.49  kb/s: 1580.78
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.60s (39.96 fps), 1873.07 kb/s, Avg QP:19.59
