# %%
# import
from transformers import AutoProcessor, AutoModel
from PIL import Image
import torch
import numpy as np
import torchvision
# Out:
# /home/zheyangq/anaconda3/envs/pytorch/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
import subprocess
import os

def compress_video(input_file, output_file, crf=28):
    """
    Compress a video file using H.265 codec (HEVC).

    Args:
    - input_file (str): Path to the input video file.
    - output_file (str): Path to save the compressed video file.
    - crf (int): Constant Rate Factor for quality control (0-51, where lower is better quality).
    """
    # command = [
    #     'ffmpeg',
    #     '-i', input_file,
    #     '-c:v', 'libx265',
    #     '-crf', str(crf),
    #     '-preset', 'medium',  # other options: ultrafast, superfast, veryfast, faster, fast, slow, slower, veryslow
    #     output_file
    # ]
    command = [
        'ffmpeg',
        '-i', input_file,
        '-c:v', 'libx265',
        '-crf', str(crf),
        '-preset', 'medium',
        '-tag:v', 'hvc1',  # Ensure compatibility with Safari
        '-c:a', 'aac',  # Use AAC audio codec for compatibility
        output_file
    ]

    subprocess.run(command, check=True)

folder = 'yolos/origin'

# loop through all the video files in the folder
for file in os.listdir(folder):
    if file.endswith('.mp4'):
        input_file = os.path.join(folder, file)
        output_file = os.path.join(folder, 'compressed_' + file)
        compress_video(input_file, output_file, crf=18)

# output_file = 'output.mp4'
# compress_video(input_file, output_file, crf=18)
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'yolos/origin/2_3_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 2268 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x320, 2264 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'yolos/origin/compressed_2_3_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x320, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.3 Lsize=     187kB time=00:00:02.10 bitrate= 728.5kbits/s speed=5.13x
# video:183kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 1.880631%
# x265 [info]: frame I:      1, Avg QP:15.73  kb/s: 1559.04
# x265 [info]: frame P:      5, Avg QP:16.77  kb/s: 1021.38
# x265 [info]: frame B:     18, Avg QP:20.77  kb/s: 463.48
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.39s (60.84 fps), 625.36 kb/s, Avg QP:19.73
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'yolos/origin/3_0_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 3923 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x320, 3919 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'yolos/origin/compressed_3_0_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x320, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=22.7 Lsize=     532kB time=00:00:02.10 bitrate=2077.1kbits/s speed=4.16x
# video:529kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.651609%
# x265 [info]: frame I:      1, Avg QP:15.68  kb/s: 4335.60
# x265 [info]: frame P:      5, Avg QP:17.13  kb/s: 3094.59
# x265 [info]: frame B:     18, Avg QP:22.16  kb/s: 1306.81
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.48s (49.52 fps), 1805.47 kb/s, Avg QP:20.84
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'yolos/origin/4_3_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 2030 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x320, 2026 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'yolos/origin/compressed_4_3_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x320, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=21.3 Lsize=     198kB time=00:00:02.10 bitrate= 770.4kbits/s speed=5.53x
# video:194kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 1.776351%
# x265 [info]: frame I:      1, Avg QP:15.62  kb/s: 1637.12
# x265 [info]: frame P:      5, Avg QP:16.51  kb/s: 1176.77
# x265 [info]: frame B:     18, Avg QP:20.89  kb/s: 464.95
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.36s (65.84 fps), 662.09 kb/s, Avg QP:19.75
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'yolos/origin/5_1_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 2254 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x320, 2250 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'yolos/origin/compressed_5_1_0002.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x320, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=20.4 Lsize=     154kB time=00:00:02.10 bitrate= 601.8kbits/s speed=6.49x
# video:151kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 2.285440%
# x265 [info]: frame I:      1, Avg QP:15.33  kb/s: 1318.40
# x265 [info]: frame P:      5, Avg QP:16.05  kb/s: 872.18
# x265 [info]: frame B:     18, Avg QP:20.00  kb/s: 370.53
# x265 [info]: Weighted P-Frames: Y:0.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.31s (78.29 fps), 514.53 kb/s, Avg QP:18.98
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from 'yolos/origin/5_3_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf60.16.100
#   Duration: 00:00:02.40, start: 0.000000, bitrate: 4284 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 512x320, 4280 kb/s, 10 fps, 10 tbr, 10240 tbn, 20 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> hevc (libx265))
# Press [q] to stop, [?] for help
# x265 [info]: HEVC encoder version 3.5+1-f0c1022b6
# x265 [info]: build info [Linux][GCC 11.2.0][64 bit] 8bit+10bit+12bit
# x265 [info]: using cpu capabilities: MMX2 SSE2Fast LZCNT SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# x265 [info]: Main profile, Level-2.1 (Main tier)
# x265 [warning]: No thread pool allocated, --wpp disabled
# x265 [warning]: No thread pool allocated, --lookahead-slices disabled
# x265 [info]: Slices                              : 1
# x265 [info]: frame threads / pool features       : 5 / none
# x265 [info]: Coding QT: max CU size, min CU size : 64 / 8
# x265 [info]: Residual QT: max TU size, max depth : 32 / 1 inter / 1 intra
# x265 [info]: ME / range / subpel / merge         : hex / 57 / 2 / 3
# x265 [info]: Keyframe min / max / scenecut / bias  : 10 / 250 / 40 / 5.00
# x265 [info]: Lookahead / bframes / badapt        : 20 / 4 / 2
# x265 [info]: b-pyramid / weightp / weightb       : 1 / 1 / 0
# x265 [info]: References / ref-limit  cu / depth  : 3 / off / on
# x265 [info]: AQ: mode / str / qg-size / cu-tree  : 2 / 1.0 / 32 / 1
# x265 [info]: Rate Control / qCompress            : CRF-18.0 / 0.60
# x265 [info]: tools: rd=3 psy-rd=2.00 early-skip rskip mode=1 signhide tmvp
# x265 [info]: tools: b-intra strong-intra-smoothing deblock sao
# Output #0, mp4, to 'yolos/origin/compressed_5_3_0003.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: hevc (hvc1 / 0x31637668), yuv420p(progressive), 512x320, q=2-31, 10 fps, 10240 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx265
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   24 fps=0.0 q=22.8 Lsize=     600kB time=00:00:02.10 bitrate=2340.0kbits/s speed=3.68x
# video:596kB audio:0kB subtitle:0kB other streams:0kB global headers:2kB muxing overhead: 0.577991%
# x265 [info]: frame I:      1, Avg QP:16.33  kb/s: 4261.44
# x265 [info]: frame P:      5, Avg QP:17.35  kb/s: 3328.11
# x265 [info]: frame B:     18, Avg QP:22.19  kb/s: 1552.73
# x265 [info]: Weighted P-Frames: Y:20.0% UV:0.0%
# x265 [info]: consecutive B-frames: 16.7% 0.0% 0.0% 33.3% 50.0%
#
# encoded 24 frames in 0.55s (43.78 fps), 2035.47 kb/s, Avg QP:20.94
